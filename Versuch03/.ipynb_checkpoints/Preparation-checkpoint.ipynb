# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 15 *10**(-6) # m
l = 10**(-6) # m
mu = .06 #m^2
tox = 30e-9 #,
eox = 35e-12 # F/m

kn = w/l*mu*eox/tox

# %%
print(f"Kn is {kn*1000}[mA/V^2]")
# Out:
# Kn is 1.05[mA/V^2]

# %% [markdown]
# ![grafik.png](attachment:bc663f80-399d-4eae-aa65-0d86326e5f71.png)

# %%
VDD = 5 #V
RD = 200 #Omega
# Search: ID
# assuming RDS -> 0
# Write down an equation for the output load line of this circuit
# Determine the values for VDS when ID = [3.3mA, 6.6mA, 10mA]
for ID in [.0033, .0066, .01]:
    VD = ID * RD
    print(f"For ID=={ID}, VD=={VD}")
# Out:
# For ID==0.0033, VD==0.66
# For ID==0.0066, VD==1.32
# For ID==0.01, VD==2.0
